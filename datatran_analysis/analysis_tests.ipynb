# %% [markdown]
# ## Importando as dependências

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ## Importando os dados

# %%
df = pd.read_csv('../datasets/datatran2024.csv', sep=';', encoding='latin1')

df.head()
# Out:
#          id data_inversa     dia_semana   horario  uf   br   km  \
# 0  571789.0   2024-01-01  segunda-feira  03:56:00  ES  101   38
# 1  571804.0   2024-01-01  segunda-feira  04:50:00  PI  343  185
# 2  571806.0   2024-01-01  segunda-feira  04:30:00  BA  116  578
# 3  571818.0   2024-01-01  segunda-feira  06:30:00  SE  101   18
# 4  571838.0   2024-01-01  segunda-feira  05:00:00  MT  364  240
#
#             municipio                                     causa_acidente  \
# 0  CONCEICAO DA BARRA                             Ultrapassagem Indevida
# 1            PIRIPIRI                        Manobra de mudança de faixa
# 2             BREJOES                   Ingestão de álcool pelo condutor
# 3    MALHADA DOS BOIS           Reação tardia ou ineficiente do condutor
# 4        RONDONOPOLIS  Condutor deixou de manter distância do veículo...
#
#                     tipo_acidente  ... feridos_graves ilesos ignorados  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 28954 entries, 0 to 28953
# Data columns (total 30 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   id                      28954 non-null  float64
#  1   data_inversa            28954 non-null  object
#  2   dia_semana              28954 non-null  object
#  3   horario                 28954 non-null  object
#  4   uf                      28954 non-null  object
#  5   br                      28954 non-null  int64
#  6   km                      28954 non-null  object
#  7   municipio               28954 non-null  object
#  8   causa_acidente          28954 non-null  object
#  9   tipo_acidente           28954 non-null  object
#  10  classificacao_acidente  28953 non-null  object
#  11  fase_dia                28954 non-null  object
#  12  sentido_via             28954 non-null  object
#  13  condicao_metereologica  28954 non-null  object
# ...

# %% [markdown]
# ## Tratamento dos dados

# %% [markdown]
# ### Trocando os valores nulos por "Nao Informado"

# %%
df.fillna("Nao informado", inplace=True)

df.info()

df.head(10)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 28954 entries, 0 to 28953
# Data columns (total 30 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   id                      28954 non-null  float64
#  1   data_inversa            28954 non-null  object
#  2   dia_semana              28954 non-null  object
#  3   horario                 28954 non-null  object
#  4   uf                      28954 non-null  object
#  5   br                      28954 non-null  int64
#  6   km                      28954 non-null  object
#  7   municipio               28954 non-null  object
#  8   causa_acidente          28954 non-null  object
#  9   tipo_acidente           28954 non-null  object
#  10  classificacao_acidente  28954 non-null  object
#  11  fase_dia                28954 non-null  object
#  12  sentido_via             28954 non-null  object
#  13  condicao_metereologica  28954 non-null  object
# ...

# %%
# Perguntas Orientadoras

# 1. Qual a proporção de acidentes por estado?

# 2. Qual a proporção de acidentes por dia da semana?

# 3. Qual a proporção de acidentes por causa de acidente? 

# 4. Qual a proporção de acidentes por trimestre? barra ou pizza

# 5. Montar um mapa de calor com a quantidade de acidentes por dia da semana utilizando as coordenadas geográficas
